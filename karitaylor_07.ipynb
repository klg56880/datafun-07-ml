# %% [markdown]
# 10.2
# Importing Classes Account and Decimal

# %%
from accounts import Account
from decimal import Decimal

# %% [markdown]
# Importing Classes Account and Decimal

# %%
value = Decimal('12.34')
account1 = Account('John Green', Decimal('50.00'))

# %% [markdown]
# Getting an Account’s Name and Balance

# %%
print(account1.name)
print(account1.balance)
# Out:
# John Green
# 75.53

# %% [markdown]
# Depositing Money into an Account

# %%
account1.deposit(Decimal('25.53'))
print(account1.balance)
# Out:
# 75.53

# %% [markdown]
# Testing method withdraw

# %%
from accounts import Account
from decimal import Decimal

# %%
account1 = Account('John Green', Decimal('50.00'))
account1.withdraw(Decimal('20.00'))
print(account1.balance)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 2
#       1 account1 = Account('John Green', Decimal('50.00'))
# ----> 2 account1.withdraw(Decimal('20.00'))
#       3 print(account1.balance)
#
# AttributeError: 'Account' object has no attribute 'withdraw'

# %% [markdown]
# 10.3
# Controlling Access to Attributes - valid balance

# %%
account1 = Account('John Green', Decimal('50.00'))
print(account1.balance)
# Out:
# 50.00

# %% [markdown]
# Controlling Access to Attributes - invalid balance

# %%
account1 = Account('John Green', Decimal('-1000.00'))
print(account1.balance)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 account1 = Account('John Green', Decimal('-1000.00'))
#       2 print(account1.balance)
#
# File c:\Users\klg56\OneDrive\Documents\datafun-07-ml\accounts.py:13, in Account.__init__(self, name, balance)
#      11 # if balance is less than 0.00, raise an exception
#      12 if balance < Decimal('0.00'):
# ---> 13     raise ValueError('Initial balance must be >= to 0.00.')
#      15 self.name = name
#      16 self.balance = balance
#
# ValueError: Initial balance must be >= to 0.00.

# %% [markdown]
# 10.4 Import Class Time

# %%
from timewithproperties import Time

# %% [markdown]
# Creating and displaying a Time Object

# %%
wake_up = Time(hour=6, minute=30)
print(wake_up)
# Out:
# 6:30:00 AM

# %% [markdown]
# Getting an Attribute Via a Property

# %%
print(wake_up.hour)
# Out:
# 6

# %% [markdown]
# Setting the Time

# %%
wake_up.set_time(hour=7, minute=45)
print(wake_up)
# Out:
# 7:45:00 AM

# %% [markdown]
# Setting an Attribute via a Property

# %%
wake_up.hour = 6
wake_up
# Out:
# Time(hour=6, minute=45, second=0)

# %% [markdown]
# Attempting to Set an Invalid Value

# %%
wake_up.hour = 100
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 wake_up.hour = 100
#
# File c:\Users\klg56\OneDrive\Documents\datafun-07-ml\timewithproperties.py:22, in Time.hour(self, hour)
#      20 """Set the hour."""
#      21 if not (0 <= hour < 24):
# ---> 22     raise ValueError(f'Hour ({hour}) must be 0-23')
#      24 self._hour = hour
#
# ValueError: Hour (100) must be 0-23

# %%
from timewithproperties import Time

# %%
t = Time()

# %%
t
# Out:
# Time(hour=0, minute=0, second=0)

# %%
t.time = (12, 30, 45)

# %%
t
# Out:
# Time(hour=12, minute=30, second=45)

# %%
t.time
# Out:
# (12, 30, 45)

# %% [markdown]
# 10.5 Demonstrating “Private” Attributes

# %%
from private import PrivateClass

# %%
my_object = PrivateClass()

# %%
my_object.public_data
# Out:
# 'public'

# %%
my_object.__private_data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 my_object.__private_data
#
# AttributeError: 'PrivateClass' object has no attribute '__private_data'

# %% [markdown]
# 10.6 Test-Driving Classes Card and DeckOfCards

# %%
from deck import DeckOfCards

# %%
deck_of_cards = DeckOfCards()

# %%
print(deck_of_cards)
# Out:
# Ace of Hearts      2 of Hearts        3 of Hearts        4 of Hearts
# 5 of Hearts        6 of Hearts        7 of Hearts        8 of Hearts
# 9 of Hearts        10 of Hearts       Jack of Hearts     Queen of Hearts
# King of Hearts     Ace of Diamonds    2 of Diamonds      3 of Diamonds
# 4 of Diamonds      5 of Diamonds      6 of Diamonds      7 of Diamonds
# 8 of Diamonds      9 of Diamonds      10 of Diamonds     Jack of Diamonds
# Queen of Diamonds  King of Diamonds   Ace of Clubs       2 of Clubs
# 3 of Clubs         4 of Clubs         5 of Clubs         6 of Clubs
# 7 of Clubs         8 of Clubs         9 of Clubs         10 of Clubs
# Jack of Clubs      Queen of Clubs     King of Clubs      Ace of Spades
# 2 of Spades        3 of Spades        4 of Spades        5 of Spades
# 6 of Spades        7 of Spades        8 of Spades        9 of Spades
# 10 of Spades       Jack of Spades     Queen of Spades    King of Spades

# %%
deck_of_cards.shuffle()

# %%
print(deck_of_cards)
# Out:
# Jack of Diamonds   6 of Spades        2 of Hearts        9 of Clubs
# 10 of Hearts       6 of Hearts        Queen of Clubs     King of Hearts
# 3 of Spades        Ace of Hearts      2 of Clubs         4 of Diamonds
# Queen of Spades    9 of Spades        Jack of Clubs      4 of Clubs
# 2 of Spades        5 of Diamonds      King of Spades     King of Clubs
# 5 of Spades        3 of Clubs         Ace of Diamonds    7 of Hearts
# 6 of Clubs         5 of Hearts        Jack of Hearts     10 of Clubs
# 8 of Clubs         7 of Clubs         10 of Diamonds     9 of Diamonds
# 8 of Spades        Jack of Spades     10 of Spades       7 of Spades
# 2 of Diamonds      3 of Hearts        9 of Hearts        3 of Diamonds
# Queen of Diamonds  7 of Diamonds      8 of Diamonds      Queen of Hearts
# 6 of Diamonds      Ace of Clubs       Ace of Spades      5 of Clubs
# 8 of Hearts        King of Diamonds   4 of Hearts        4 of Spades

# %%
deck_of_cards.deal_card()
# Out:
# Card(face='Jack', suit='Diamonds')

# %%
card = deck_of_cards.deal_card()

# %%
str(card)
# Out:
# '6 of Spades'

# %%
card.image_name
# Out:
# '6_of_Spades.png'

# %% [markdown]
# Displaying Card Images with Matplotlib

# %%
from deck import DeckOfCards

# %%
deck_of_cards = DeckOfCards()

# %%
# %matplotlib
# Out:
# Using matplotlib backend: QtAgg

# %%
from pathlib import Path

# %%
path = Path('.').joinpath('card_images')

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.image as mpimg

# %%
figure, axes_list = plt.subplots(nrows=4, ncols=13)

# added next two statements to increase figure size in notebook
figure.set_figwidth(16)
figure.set_figheight(9)

for axes in axes_list.ravel():
    axes.get_xaxis().set_visible(False)
    axes.get_yaxis().set_visible(False)
    image_name = deck_of_cards.deal_card().image_name
    img = mpimg.imread(str(path.joinpath(image_name).resolve()))
    axes.imshow(img)

figure.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[61], line 11
#       9     axes.get_yaxis().set_visible(False)
#      10     image_name = deck_of_cards.deal_card().image_name
# ---> 11     img = mpimg.imread(str(path.joinpath(image_name).resolve()))
#      12     axes.imshow(img)
#      14 figure.tight_layout()
#
# File c:\Users\klg56\anaconda3\Lib\site-packages\matplotlib\image.py:1525, in imread(fname, format)
#    1518 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1519     # Pillow doesn't handle URLs directly.
#    1520     raise ValueError(
#    1521         "Please open the URL for reading and pass the "
#    1522         "result to Pillow, e.g. with "
#    1523         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1524         )
# -> 1525 with img_open(fname) as image:
#    1526     return (_pil_png_to_float_array(image)
#    1527             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1528             pil_to_array(image))
#
# File c:\Users\klg56\anaconda3\Lib\site-packages\PIL\ImageFile.py:125, in ImageFile.__init__(self, fp, filename)
#     121 self.decodermaxblock = MAXBLOCK
#     123 if is_path(fp):
#     124     # filename
# --> 125     self.fp = open(fp, "rb")
#     126     self.filename = fp
#     127     self._exclusive_fp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\klg56\\OneDrive\\Documents\\datafun-07-ml\\card_images\\5_of_Hearts.png'

# %% [markdown]
# 10.8 Testing Class CommissionEmployee

# %%
from commisionemployee import CommissionEmployee

# %%
from decimal import Decimal

# %%
c = CommissionEmployee('Sue', 'Jones', '333-33-3333', Decimal('10000.00'), Decimal('0.06'))

# %%
c
# Out:
# CommissionEmployee: Sue Jones
# social security number: 333-33-3333
# gross sales: 10000.00
# commission rate: 0.06

# %%
print(f'{c.earnings():,.2f}')
# Out:
# 600.00

# %%
c.gross_sales = Decimal('20000.00')

# %%
c.commission_rate = Decimal('0.1')

# %%
print(f'{c.earnings():,.2f}')
# Out:
# 2,000.00

# %% [markdown]
# 10.16 Linear Relationships

# %%
c = lambda f: 5 / 9 * (f - 32)

# %%
temps = [(f, c(f)) for f in range(0, 101, 10)]

# %%
import pandas as pd

# %%
temps_df = pd.DataFrame(temps, columns=['Fahrenheit', 'Celsius'])

# %%
axes = temps_df.plot(x='Fahrenheit', y='Celsius', style='.-')
y_label = axes.set_ylabel('Celsius')

# %% [markdown]
# Loading the Average High Temperatures into a DataFrame

# %%
nyc = pd.read_csv('ave_hi_nyc_jan_1895-2018.csv')

# %%
nyc.head()
# Out:
#      Date  Value  Anomaly
# 0  189501   34.2     -3.2
# 1  189601   34.7     -2.7
# 2  189701   35.5     -1.9
# 3  189801   39.6      2.2
# 4  189901   36.4     -1.0

# %%
nyc.tail()
# Out:
#        Date  Value  Anomaly
# 119  201401   35.5     -1.9
# 120  201501   36.1     -1.3
# 121  201601   40.8      3.4
# 122  201701   42.8      5.4
# 123  201801   38.7      1.3

# %%
nyc.columns = ['Date', 'Temperature', 'Anomaly']

# %%
nyc.head(3)
# Out:
#      Date  Temperature  Anomaly
# 0  189501         34.2     -3.2
# 1  189601         34.7     -2.7
# 2  189701         35.5     -1.9

# %%
nyc.Date.dtype
# Out:
# dtype('int64')

# %%
nyc.Date = nyc.Date.floordiv(100)

# %%
nyc.head(3)
# Out:
#    Date  Temperature  Anomaly
# 0  1895         34.2     -3.2
# 1  1896         34.7     -2.7
# 2  1897         35.5     -1.9

# %%
nyc.Temperature.describe()
# Out:
# count    124.000000
# mean      37.595161
# std        4.539848
# min       26.100000
# 25%       34.575000
# 50%       37.600000
# 75%       40.600000
# max       47.600000
# Name: Temperature, dtype: float64

# %% [markdown]
# Forecasting Future January Average High Temperatures

# %%
from scipy import stats

# %%
linear_regression = stats.linregress(x=nyc.Date, y=nyc.Temperature)

# %%
linear_regression.slope
# Out:
# 0.014771361132966163

# %%
linear_regression.intercept
# Out:
# 8.694993233674289

# %%
linear_regression.slope * 2019 + linear_regression.intercept
# Out:
# 38.51837136113297

# %%
linear_regression.slope * 1890 + linear_regression.intercept
# Out:
# 36.612865774980335

# %%
import seaborn as sns

# %%
sns.set_style('whitegrid')
axes = sns.regplot(x=nyc.Date, y=nyc.Temperature)

# %%
axes.set_ylim(10, 70)
# Out:
# (10.0, 70.0)

# %% [markdown]
# 15.2 Classification with k-nearest neighbors and the digits dataset

# %%
from sklearn.datasets import load_digits

# %%
digits = load_digits()

# %%
print(digits.DESCR)
# Out:
# .. _digits_dataset:
#
# Optical recognition of handwritten digits dataset
# --------------------------------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 1797
#     :Number of Attributes: 64
#     :Attribute Information: 8x8 image of integer pixels in the range 0..16.
#     :Missing Attribute Values: None
#     :Creator: E. Alpaydin (alpaydin '@' boun.edu.tr)
#     :Date: July; 1998
#
# This is a copy of the test set of the UCI ML hand-written digits datasets
# https://archive.ics.uci.edu/ml/datasets/Optical+Recognition+of+Handwritten+Digits
#
# The data set contains images of hand-written digits: 10 classes where
# each class refers to a digit.
#
# Preprocessing programs made available by NIST were used to extract
# normalized bitmaps of handwritten digits from a preprinted form. From a
# total of 43 people, 30 contributed to the training set and different 13
# to the test set. 32x32 bitmaps are divided into nonoverlapping blocks of
# 4x4 and the number of on pixels are counted in each block. This generates
# an input matrix of 8x8 where each element is an integer in the range
# 0..16. This reduces dimensionality and gives invariance to small
# distortions.
#
# For info on NIST preprocessing routines, see M. D. Garris, J. L. Blue, G.
# T. Candela, D. L. Dimmick, J. Geist, P. J. Grother, S. A. Janet, and C.
# L. Wilson, NIST Form-Based Handprint Recognition System, NISTIR 5469,
# 1994.
#
# .. topic:: References
#
#   - C. Kaynak (1995) Methods of Combining Multiple Classifiers and Their
#     Applications to Handwritten Digit Recognition, MSc Thesis, Institute of
#     Graduate Studies in Science and Engineering, Bogazici University.
#   - E. Alpaydin, C. Kaynak (1998) Cascading Classifiers, Kybernetika.
#   - Ken Tang and Ponnuthurai N. Suganthan and Xi Yao and A. Kai Qin.
#     Linear dimensionalityreduction using relevance weighted LDA. School of
#     Electrical and Electronic Engineering Nanyang Technological University.
#     2005.
#   - Claudio Gentile. A New Approximate Maximal Margin Classification
#     Algorithm. NIPS. 2000.

# %%
digits.target[::100]
# Out:
# array([0, 4, 1, 7, 4, 8, 2, 2, 4, 4, 1, 9, 7, 3, 2, 1, 2, 5])

# %%
digits.data.shape
# Out:
# (1797, 64)

# %%
digits.target.shape
# Out:
# (1797,)

# %%
digits.images[13]
# Out:
# array([[ 0.,  2.,  9., 15., 14.,  9.,  3.,  0.],
#        [ 0.,  4., 13.,  8.,  9., 16.,  8.,  0.],
#        [ 0.,  0.,  0.,  6., 14., 15.,  3.,  0.],
#        [ 0.,  0.,  0., 11., 14.,  2.,  0.,  0.],
#        [ 0.,  0.,  0.,  2., 15., 11.,  0.,  0.],
#        [ 0.,  0.,  0.,  0.,  2., 15.,  4.,  0.],
#        [ 0.,  1.,  5.,  6., 13., 16.,  6.,  0.],
#        [ 0.,  2., 12., 12., 13., 11.,  0.,  0.]])

# %%
digits.data[13]
# Out:
# array([ 0.,  2.,  9., 15., 14.,  9.,  3.,  0.,  0.,  4., 13.,  8.,  9.,
#        16.,  8.,  0.,  0.,  0.,  0.,  6., 14., 15.,  3.,  0.,  0.,  0.,
#         0., 11., 14.,  2.,  0.,  0.,  0.,  0.,  0.,  2., 15., 11.,  0.,
#         0.,  0.,  0.,  0.,  0.,  2., 15.,  4.,  0.,  0.,  1.,  5.,  6.,
#        13., 16.,  6.,  0.,  0.,  2., 12., 12., 13., 11.,  0.,  0.])

# %%
import matplotlib.pyplot as plt

# %%
figure, axes = plt.subplots(nrows=4, ncols=6, figsize=(6, 4))

### Displaying Each Image and Removing the Axes Labels 

for item in zip(axes.ravel(), digits.images, digits.target):
    axes, image, target = item
    axes.imshow(image, cmap=plt.cm.gray_r)
    axes.set_xticks([])  # remove x-axis tick marks
    axes.set_yticks([])  # remove y-axis tick marks
    axes.set_title(target)
plt.tight_layout()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(digits.data, digits.target, random_state=11)

# %%
X_train.shape
# Out:
# (1347, 64)

# %%
X_test.shape
# Out:
# (450, 64)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(X=X_train, y=y_train)
# Out:
# KNeighborsClassifier()

# %%
predicted = knn.predict(X=X_test)

# %%
expected = y_test

# %%
predicted[:20]
# Out:
# array([0, 4, 9, 9, 3, 1, 4, 1, 5, 0, 4, 9, 4, 1, 5, 3, 3, 8, 5, 6])

# %%
expected[:20]
# Out:
# array([0, 4, 9, 9, 3, 1, 4, 1, 5, 0, 4, 9, 4, 1, 5, 3, 3, 8, 3, 6])

# %%
wrong = [(p, e) for (p, e) in zip(predicted, expected) if p != e]

# %%
wrong
# Out:
# [(5, 3),
#  (8, 9),
#  (4, 9),
#  (7, 3),
#  (7, 4),
#  (2, 8),
#  (9, 8),
#  (3, 8),
#  (3, 8),
#  (1, 8)]

# %% [markdown]
# 15.4 Time Series and Simple Linear Regression

# %%
import pandas as pd

# %%
nyc = pd.read_csv('ave_hi_nyc_jan_1895-2018.csv')

# %%
nyc.columns = ['Date', 'Temperature', 'Anomaly']

# %%
nyc.Date = nyc.Date.floordiv(100)

# %%
nyc.head(3)
# Out:
#    Date  Temperature  Anomaly
# 0  1895         34.2     -3.2
# 1  1896         34.7     -2.7
# 2  1897         35.5     -1.9

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(nyc.Date.values.reshape(-1, 1), nyc.Temperature.values, random_state=11)

# %%
X_train.shape
# Out:
# (93, 1)

# %%
X_test.shape
# Out:
# (31, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_regression = LinearRegression()

# %%
linear_regression.fit(X=X_train, y=y_train)
# Out:
# LinearRegression()

# %%
linear_regression.coef_
# Out:
# array([0.01939167])

# %%
linear_regression.intercept_
# Out:
# -0.30779820252656265

# %%
predicted = linear_regression.predict(X_test)

# %%
expected = y_test

# %%
for p, e in zip(predicted[::5], expected[::5]):
    print(f'predicted: {p:.2f}, expected: {e:.2f}')
# Out:
# predicted: 37.86, expected: 31.70
# predicted: 38.69, expected: 34.80
# predicted: 37.00, expected: 39.40
# predicted: 37.25, expected: 45.70
# predicted: 38.05, expected: 32.30
# predicted: 37.64, expected: 33.80
# predicted: 36.94, expected: 39.70

# %%
predict = (lambda x: linear_regression.coef_ * x + linear_regression.intercept_)

# %%
predict(2019)
# Out:
# array([38.84399018])

# %%
predict(1890)
# Out:
# array([36.34246432])

# %%
import seaborn as sns

# %%
axes = sns.scatterplot(data=nyc, x='Date', y='Temperature',
    hue='Temperature', palette='winter', legend=False)

# %%
axes.set_ylim(10, 70)
# Out:
# (10.0, 70.0)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([min(nyc.Date.values), max(nyc.Date.values)])
y = predict(x)
line = plt.plot(x, y)
